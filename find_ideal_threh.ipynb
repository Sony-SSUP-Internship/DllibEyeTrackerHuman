# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = plt.imread("E:\\Projects Continued\\DllibEyeTrackerHuman\\eyeimgs\\img.png")

# %%
plt.imshow(img)

# %%
v =  plt.hist(img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram

# %%
#CalcDelta
delvalue = 100
np.max(v[0])
# Out:
# np.float64(868.0)
